# %% [markdown]
# <a href="https://colab.research.google.com/github/swetapanda05/ECommerceApp/blob/main/Apython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
PIN = 1234
attempts = 3

while attempts > 0:
    entered_pin = int(input("Enter your PIN: "))

    if entered_pin == PIN:
        print("PIN verified successfully.\n")
        break
    else:
        attempts -= 1
        print(f"Wrong PIN. Attempts left: {attempts}")

if attempts == 0:
    print("Too many wrong attempts. Access denied.")
    exit()

bal = 0
trans = []

while True:
    print("\n1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Transaction History")
    print("5. Exit")

    choice = int(input("Enter your choice = "))

    if choice == 1:
        amt = int(input("Enter the amount you want to deposit = "))
        bal += amt
        trans.append(f"Deposit: {amt}")
        print("Amount deposited successfully.")

    elif choice == 2:
        amt = int(input("Enter the amount to withdraw = "))
        if amt <= bal:
            bal -= amt
            trans.append(f"Withdraw: {amt}")
            print("Amount withdrawn successfully.")
        else:
            print("Insufficient balance.")

    elif choice == 3:
        print("Current Balance =", bal)

    elif choice == 4:
        if not trans:
            print("No transactions yet.")
        else:
            print("Transaction History:")
            for t in trans:
                print(t)

    elif choice == 5:
        print("Thank you!")
        break

    else:
        print("Invalid choice. Please try again.")

# %%
PIN = 4444

def check_pin():
    attempts = 3
    while attempts > 0:
        pin = int(input("Enter your PIN: "))
        if pin == PIN:
            print("PIN verified successfully.\n")
            return True
        else:
            attempts -= 1
            print(f"Wrong PIN. Attempts left: {attempts}")
    print("Too many wrong attempts. Access denied.")
    return False


def deposit(bal, trans):
    amt = int(input("Enter the amount you want to deposit = "))
    bal += amt
    trans.append(f"Deposit: {amt}")
    print("Amount deposited successfully.")
    return bal


def withdraw(bal, trans):
    amt = int(input("Enter the amount to withdraw = "))
    if amt <= bal:
        bal -= amt
        trans.append(f"Withdraw: {amt}")
        print("Amount withdrawn successfully.")
    else:
        print("Insufficient balance.")
    return bal


def check_balance(bal):
    print("Current Balance =", bal)


def transaction_history(trans):
    if not trans:
        print("No transactions yet.")
    else:
        print("Transaction History:")
        for t in trans:
            print(t)


def atm_menu():
    bal = 0
    trans = []

    while True:
        print("\n1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Transaction History")
        print("5. Exit")

        choice = int(input("Enter your choice = "))

        if choice == 1:
            bal = deposit(bal, trans)

        elif choice == 2:
            bal = withdraw(bal, trans)

        elif choice == 3:
            check_balance(bal)

        elif choice == 4:
            transaction_history(trans)

        elif choice == 5:
            print("Thank you!")
            break

        else:
            print("Invalid choice. Please try again.")


if check_pin():
    atm_menu()

# %%
books = []

def add_book():
    book_id = input("Enter Book ID: ")
    name = input("Enter Book Name: ")
    author = input("Enter Author Name: ")
    status = "Available"

    book = [book_id, name, author, status]
    books.append(book)
    print("Book added successfully")

def display_books():
    if len(books) == 0:
        print("No books available")
    else:
        for book in books:
            print("Book ID:", book[0])
            print("Book Name:", book[1])
            print("Author:", book[2])
            print("Status:", book[3])
            print("---------------------")

def issue_book():
    book_id = input("Enter Book ID to issue: ")
    found = False

    for book in books:
        if book[0] == book_id:
            found = True
            if book[3] == "Available":
                book[3] = "Issued"
                print("Book issued successfully")
            else:
                print("Book already issued")

    if found == False:
        print("Book not found")

def return_book():
    book_id = input("Enter Book ID to return: ")
    found = False

    for book in books:
        if book[0] == book_id:
            found = True
            if book[3] == "Issued":
                book[3] = "Available"
                print("Book returned successfully")
            else:
                print("Book was not issued")

    if found == False:
        print("Book not found")

while True:
    print("\nLibrary Management System")
    print("1. Add Book")
    print("2. Display Books")
    print("3. Issue Book")
    print("4. Return Book")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_book()
    elif choice == "2":
        display_books()
    elif choice == "3":
        issue_book()
    elif choice == "4":
        return_book()
    elif choice == "5":
        print("Thank you")
        break
    else:
        print("Invalid choice")

# %%
def red_light():
    print("RED Light - Stop")

def yellow_light():
    print("YELLOW Light - Wait")

def green_light():
    print("GREEN Light - Go")

while True:
    print("\nTraffic Light Simulation")
    print("1. Red Light")
    print("2. Yellow Light")
    print("3. Green Light")
    print("4. Automatic Cycle")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        red_light()
    elif choice == "2":
        yellow_light()
    elif choice == "3":
        green_light()
    elif choice == "4":
        red_light()
        yellow_light()
        green_light()
    elif choice == "5":
        print("Program Ended")
        break
    else:
        print("Invalid Choice")

# %%
python.ipynb_
Double-click (or enter) to edit

ATM


[ ]
PIN = 1234attempts = 3while attempts > 0:    entered_pin = int(input("Enter your PIN: "))    if entered_pin == PIN:        print("PIN verified successfully.\n")        break    else:        attempts -= 1        print(f"Wrong PIN. Attempts left: {attempts}")if attempts == 0:    print("Too many wrong attempts. Access denied.")    exit()bal = 0trans = []while True:    print("\n1. Deposit")    print("2. Withdraw")    print("3. Check Balance")    print("4. Transaction History")    print("5. Exit")    choice = int(input("Enter your choice = "))    if choice == 1:        amt = int(input("Enter the amount you want to deposit = "))        bal += amt        trans.append(f"Deposit: {amt}")        print("Amount deposited successfully.")    elif choice == 2:        amt = int(input("Enter the amount to withdraw = "))        if amt <= bal:            bal -= amt            trans.append(f"Withdraw: {amt}")            print("Amount withdrawn successfully.")        else:            print("Insufficient balance.")    elif choice == 3:        print("Current Balance =", bal)    elif choice == 4:        if not trans:            print("No transactions yet.")        else:            print("Transaction History:")            for t in trans:                print(t)    elif choice == 5:        print("Thank you!")        break    else:        print("Invalid choice. Please try again.")

 Enter your PIN: 5678
Wrong PIN. Attempts left: 2
Enter your PIN: 1234
PIN verified successfully.


1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 5
Thank you!

[ ]
PIN = 4444

def check_pin():
    attempts = 3
    while attempts > 0:
        pin = int(input("Enter your PIN: "))
        if pin == PIN:
            print("PIN verified successfully.\n")
            return True
        else:
            attempts -= 1
            print(f"Wrong PIN. Attempts left: {attempts}")
    print("Too many wrong attempts. Access denied.")
    return False


def deposit(bal, trans):
    amt = int(input("Enter the amount you want to deposit = "))
    bal += amt
    trans.append(f"Deposit: {amt}")
    print("Amount deposited successfully.")
    return bal


def withdraw(bal, trans):
    amt = int(input("Enter the amount to withdraw = "))
    if amt <= bal:
        bal -= amt
        trans.append(f"Withdraw: {amt}")
        print("Amount withdrawn successfully.")
    else:
        print("Insufficient balance.")
    return bal


def check_balance(bal):
    print("Current Balance =", bal)


def transaction_history(trans):
    if not trans:
        print("No transactions yet.")
    else:
        print("Transaction History:")
        for t in trans:
            print(t)


def atm_menu():
    bal = 0
    trans = []

    while True:
        print("\n1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Transaction History")
        print("5. Exit")

        choice = int(input("Enter your choice = "))

        if choice == 1:
            bal = deposit(bal, trans)

        elif choice == 2:
            bal = withdraw(bal, trans)

        elif choice == 3:
            check_balance(bal)

        elif choice == 4:
            transaction_history(trans)

        elif choice == 5:
            print("Thank you!")
            break

        else:
            print("Invalid choice. Please try again.")


if check_pin():
    atm_menu()

 Enter your PIN: 4444
PIN verified successfully.


1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 1
Enter the amount you want to deposit = 1000
Amount deposited successfully.

1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 2
Enter the amount to withdraw = 999
Amount withdrawn successfully.

1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 3
Current Balance = 1

1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 4
Transaction History:
Deposit: 1000
Withdraw: 999

1. Deposit
2. Withdraw
3. Check Balance
4. Transaction History
5. Exit
Enter your choice = 5
Thank you!
1.⁠ ⁠Find common elements between two lists using set


[ ]
l1=[1,2,3,4]l2=[2,4,6,7]com=set(l1)&set(l2)print(com)

 {2, 4}
Remove duplicate words from a sentence using set

[ ]
sen = "hello, my name is santoshi name is my"words = sen.split()unique_words = set(words)result = " ".join(unique_words)print(result)

 is santoshi hello, my name
Check if 2 strings are anagrams using set and logic

[ ]
s1 = "listen"s2 = "silent"if set(s1) == set(s2) and len(s1) == len(s2):    print("Anagrams")else:    print("Not anagrams")

 Anagrams
Find elements present in first list but not in second using set

[ ]
list1 = [1, 2, 3, 4]list2 = [3, 4, 5]result = set(list1) - set(list2)print(result)

 {1, 2}
Check if all characters in a string are unique using set

[ ]
s = "python"

if len(s) == len(set(s)):
    print("All characters are unique")
else:
    print("Duplicate characters found")

 All characters are unique
Count number of distinct elements in a list using set

[ ]
lst = [1, 2, 2, 3, 4, 4, 5]

count = len(set(lst))
print(count)

 5
Find symmetric difference between 2 sets without built-in methods

[ ]
set1 = {1, 2, 3}
set2 = {3, 4, 5}

result = set()

for i in set1:
    if i not in set2:
        result.add(i)

for i in set2:
    if i not in set1:
        result.add(i)

print(result)

 {1, 2, 4, 5}
Remove common characters from 2 strings using set

[ ]
s1 = "hello"
s2 = "world"

common = set(s1) & set(s2)

res1 = "".join([c for c in s1 if c not in common])
res2 = "".join([c for c in s2 if c not in common])

print(res1, res2)

 he wrd
Check if one set is a subset of another without built-in functions

[ ]
set1 = {1, 2}
set2 = {1, 2, 3, 4}

is_subset = True

for i in set1:
    if i not in set2:
        is_subset = False
        break

print("Subset" if is_subset else "Not a subset")

 Subset
Find repeated elements in a list using set

[ ]
lst = [1, 2, 3, 2, 4, 5, 1]

seen = set()
repeated = set()

for i in lst:
    if i in seen:
        repeated.add(i)
    else:
        seen.add(i)

print(repeated)

 {1, 2}
EVENT TRACKER


[ ]
entered_persons = set()
rejected_persons = set()

num_persons = 5

print("Event Tracker: Enter 5 persons\n")

for i in range(num_persons):
    name = input(f"Enter name of person {i+1}: ").strip()

    if name in entered_persons:
        print(f"Entry rejected! {name} has already entered.")
        rejected_persons.add(name)
    else:
        print(f"Entry accepted! Welcome {name}.")
        entered_persons.add(name)

print("\n--- Event Entry Summary ---")
print(f"Persons entered successfully ({len(entered_persons)}): {', '.join(entered_persons)}")
print(f"Persons rejected ({len(rejected_persons)}): {', '.join(rejected_persons)}")
print(f"Total persons who entered: {len(entered_persons)}")
print(f"Total persons rejected / duplicate entries: {len(rejected_persons)}")
print(f"Total persons not entered: {num_persons - len(entered_persons)}")
 Event Tracker: Enter 5 persons

Enter name of person 1: bhim
Entry accepted! Welcome bhim.
Enter name of person 2: raj
Entry accepted! Welcome raj.
Enter name of person 3: raj
Entry rejected! raj has already entered.
Enter name of person 4: san
Entry accepted! Welcome san.
Enter name of person 5: shr
Entry accepted! Welcome shr.

--- Event Entry Summary ---
Persons entered successfully (4): raj, shr, san, bhim
Persons rejected (1): raj
Total persons who entered: 4
Total persons rejected / duplicate entries: 1
Total persons not entered: 1

[ ]
entered_persons = set()
rejected_persons = set()

n = int(input("Enter the number of persons: "))

for i in range(n):
    name = input("Enter name of person: ")

    if name in entered_persons:
        print(name, "Entry rejected!")
        rejected_persons.add(name)
    else:
        print(name, "Entry accepted!")
        entered_persons.add(name)

print("Event Tracker!")

print("Total entered persons:")
for name in entered_persons:
    print(name)

print("Rejected persons:")
for name in rejected_persons:
    print(name)
 Enter the number of persons: 2
Enter name of person: siri
siri Entry accepted!
Enter name of person: SIRI
SIRI Entry accepted!
Event Tracker!
Total entered persons:
SIRI
siri
Rejected persons:
DICTIONARY


[ ]
key without values are possible using "none" keyword
HOTEL ROOM RESERVATION


[ ]
rooms = {
    101: None,
    102: None,
    103: None,
    104: None,
    105: None
}

while True:
    print("\n1. View Rooms")
    print("2. Book Room")
    print("3. Cancel Booking")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        for room, name in rooms.items():
            if name is None:
                print(room, "is available")
            else:
                print(room, "is booked by", name)

    elif choice == 2:
        room = int(input("Enter room number: "))
        if rooms.get(room) is None:
            name = input("Enter your name: ")
            rooms[room] = name
            print("Room booked successfully")
        else:
            print("Room already booked")

    elif choice == 3:
        room = int(input("Enter room number: "))
        if rooms.get(room) is not None:
            rooms[room] = None
            print("Booking cancelled")
        else:
            print("Room is already empty")

    elif choice == 4:
        print("Thank you!")
        break

    else:
        print("Invalid choice")


1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 1
101 is available
102 is available
103 is available
104 is available
105 is available

1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 2
Enter room number: 104
Enter your name: bhim
Room booked successfully

1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 2
Enter room number: 104
Room already booked

1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 2
Enter room number: 101
Enter your name: raj
Room booked successfully

1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 3
Enter room number: 101
Booking cancelled

1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 4
Thank you!

[ ]
rooms = {
    101: None,
    102: None,
    103: None,
    104: None,
    105: None
}

while True:
    print("\n1. View Rooms")
    print("2. Book Room")
    print("3. Cancel Booking")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        for room in rooms:
            if rooms[room] is None:
                print(room, "is available")
            else:
                print(room, "is booked by", rooms[room])

    elif choice == 2:
        room = int(input("Enter room number: "))

        if room not in rooms:
            print("Invalid room number")

        elif rooms[room] is None:
            name = input("Enter your name: ")
            rooms[room] = name
            print("Room booked successfully")

        else:
            print("Room already booked")

    elif choice == 3:
        room = int(input("Enter room number: "))

        if room not in rooms:
            print("Invalid room number")

        elif rooms[room] is not None:
            rooms[room] = None
            print("Booking cancelled")

        else:
            print("Room is already empty")

    elif choice == 4:
        print("Thank you!")
        break

    else:
        print("Invalid choice")


1. View Rooms
2. Book Room
3. Cancel Booking
4. Exit
Enter your choice: 4
Thank you!
Double-click (or enter) to edit


[ ]
students = {}   # student_id : {name, courses}
courses = {}    # course_id : course_name

while True:
    print("\n1. Add Student")
    print("2. Add Course")
    print("3. Enroll Student")
    print("4. Mark Attendance")
    print("5. Assign Grade")
    print("6. Drop Course")
    print("7. Student Report")
    print("8. Course-wise Report")
    print("9. Exit")

    choice = input("Enter your choice: ")



    if choice == '1':
        sid = input("Enter Student ID: ")
        name = input("Enter Student Name: ")
        students[sid] = {"name": name, "courses": {}}
        print("Student added successfully!")


    elif choice == '2':
        cid = input("Enter Course ID: ")
        cname = input("Enter Course Name: ")
        courses[cid] = cname
        print("Course added successfully!")


    elif choice == '3':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in courses:
            students[sid]["courses"][cid] = {"attendance": 0, "grade": None}
            print("Student enrolled successfully!")
        else:
            print("Invalid Student or Course ID")


    elif choice == '4':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in students[sid]["courses"]:
            students[sid]["courses"][cid]["attendance"] += 1
            print("Attendance marked!")
        else:
            print("Enrollment not found")


    elif choice == '5':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")
        grade = input("Enter Grade: ")

        if sid in students and cid in students[sid]["courses"]:
            students[sid]["courses"][cid]["grade"] = grade
            print("Grade assigned successfully!")
        else:
            print("Enrollment not found")


    elif choice == '6':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in students[sid]["courses"]:
            del students[sid]["courses"][cid]
            print("Course dropped successfully!")
        else:
            print("Enrollment not found")


    elif choice == '7':
        sid = input("Enter Student ID: ")

        if sid in students:
            print("\nStudent Name:", students[sid]["name"])
            for cid, details in students[sid]["courses"].items():
                print("Course:", courses[cid],
                      "| Attendance:", details["attendance"],
                      "| Grade:", details["grade"])
        else:
            print("Student not found")


    elif choice == '8':
        cid = input("Enter Course ID: ")

        if cid in courses:
            print("\nCourse Name:", courses[cid])
            for sid, sdata in students.items():
                if cid in sdata["courses"]:
                    details = sdata["courses"][cid]
                    print("Student:", sdata["name"],
                          "| Attendance:", details["attendance"],
                          "| Grade:", details["grade"])
        else:
            print("Course not found")


    elif choice == '9':
        print("Program terminated.")
        break

    else:
        print("Invalid choice, try again!")


[ ]
students = {}   # student_id : {name, courses}courses = {}    # course_id : course_namedef add_student():    sid = input("Enter student ID: ")    name = input("Enter student name: ")    students[sid] = {"name": name, "courses": {}}    print("Student added successfully!")def add_course():    cid = input("Enter course ID: ")    cname = input("Enter course name: ")    courses[cid] = cname    print("Course added successfully!")# Enroll student in coursedef enroll_student():    sid = input("Enter student ID: ")    cid = input("Enter course ID: ")    if sid in students and cid in courses:        students[sid]["courses"][cid] = {"attendance": 0, "grade": None}        print("Student enrolled successfully!")    else:        print("Invalid student or course ID")# Mark attendancedef mark_attendance():    sid = input("Student ID: ")    cid = input("Course ID: ")    if sid in students and cid in students[sid]["courses"]:        students[sid]["courses"][cid]["attendance"] += 1        print("Attendance marked!")    else:        print("Enrollment not found")def assign_grade():    sid = input("Student ID: ")    cid = input("Course ID: ")    grade = input("Enter grade: ")    if sid in students and cid in students[sid]["courses"]:        students[sid]["courses"][cid]["grade"] = grade        print("Grade assigned!")    else:        print("Enrollment not found")# Drop coursedef drop_course():    sid = input("Student ID: ")    cid = input("Course ID: ")    if sid in students and cid in students[sid]["courses"]:        del students[sid]["courses"][cid]        print("Course dropped successfully!")    else:        print("Enrollment not found")# Student reportdef student_report():    sid = input("Student ID: ")    if sid in students:        print("\nStudent Name:", students[sid]["name"])        for cid, details in students[sid]["courses"].items():            print(f"Course: {courses[cid]}, Attendance: {details['attendance']}, Grade: {details['grade']}")    else:        print("Student not found")# Course-wise reportdef course_report():    cid = input("Course ID: ")    if cid in courses:        print("\nCourse:", courses[cid])        for sid, sdata in students.items():            if cid in sdata["courses"]:                details = sdata["courses"][cid]                print(f"Student: {sdata['name']}, Attendance: {details['attendance']}, Grade: {details['grade']}")    else:        print("Course not found")# Menu-driven programwhile True:    print("\n1.Add Student\n2.Add Course\n3.Enroll Student\n4.Mark Attendance\n5.Assign Grade")    print("6.Drop Course\n7.Student Report\n8.Course Report\n9.Exit")    choice = input("Enter choice: ")    if choice == '1':        add_student()    elif choice == '2':        add_course()    elif choice == '3':        enroll_student()    elif choice == '4':        mark_attendance()    elif choice == '5':        assign_grade()    elif choice == '6':        drop_course()    elif choice == '7':        student_report()    elif choice == '8':        course_report()    elif choice == '9':        print("Program ended.")        break    else:        print("Invalid choice")


[ ]

Start coding or generate with AI.
FUNCTIONS-a group of statements that is executed when it is called from some point of program.

user defined function-defined by programmers.

built-in functions-predefined functions.Eg-> min(),max(),int(),float()

standard libraries-

external libraries-

parameters-we pass input data to a function(defined during function defination)

arguments- values passed during calling a function

type of arguments

1.positional->argument passed to afunction in correct positional order.

2.default->when function call is made without arguments, the function has default values for it

3.keyword->naming the parameter when caliing the function

4.variable length->variable number of arguments to our function

scope of vaiables

global

local


[ ]
pass=4444;
def check_pin():
  attempt=3
  if attempt>0:
    pin=int(input("enter pin:"))
    if pin==pass:
      print("correct pin")
    else:
      attempt=attempt-1
      print(f"incorrect pin. attempts left:{attempt}")
  return false

def deposit(bal,trans):


[ ]
books = []

def add_book():
    book_id = input("Enter Book ID: ")
    name = input("Enter Book Name: ")
    author = input("Enter Author Name: ")
    status = "Available"

    book = [book_id, name, author, status]
    books.append(book)
    print("Book added successfully")

def display_books():
    if len(books) == 0:
        print("No books available")
    else:
        for book in books:
            print("Book ID:", book[0])
            print("Book Name:", book[1])
            print("Author:", book[2])
            print("Status:", book[3])
            print("---------------------")

def issue_book():
    book_id = input("Enter Book ID to issue: ")
    found = False

    for book in books:
        if book[0] == book_id:
            found = True
            if book[3] == "Available":
                book[3] = "Issued"
                print("Book issued successfully")
            else:
                print("Book already issued")

    if found == False:
        print("Book not found")

def return_book():
    book_id = input("Enter Book ID to return: ")
    found = False

    for book in books:
        if book[0] == book_id:
            found = True
            if book[3] == "Issued":
                book[3] = "Available"
                print("Book returned successfully")
            else:
                print("Book was not issued")

    if found == False:
        print("Book not found")

while True:
    print("\nLibrary Management System")
    print("1. Add Book")
    print("2. Display Books")
    print("3. Issue Book")
    print("4. Return Book")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_book()
    elif choice == "2":
        display_books()
    elif choice == "3":
        issue_book()
    elif choice == "4":
        return_book()
    elif choice == "5":
        print("Thank you")
        break
    else:
        print("Invalid choice")

[ ]
def red_light():
    print("RED Light - Stop")

def yellow_light():
    print("YELLOW Light - Wait")

def green_light():
    print("GREEN Light - Go")

while True:
    print("\nTraffic Light Simulation")
    print("1. Red Light")
    print("2. Yellow Light")
    print("3. Green Light")
    print("4. Automatic Cycle")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        red_light()
    elif choice == "2":
        yellow_light()
    elif choice == "3":
        green_light()
    elif choice == "4":
        red_light()
        yellow_light()
        green_light()
    elif choice == "5":
        print("Program Ended")
        break
    else:
        print("Invalid Choice")

Traffic Light Simulation
1. Red Light
2. Yellow Light
3. Green Light
4. Automatic Cycle
5. Exit
Enter your choice: 1
RED Light - Stop

Traffic Light Simulation
1. Red Light
2. Yellow Light
3. Green Light
4. Automatic Cycle
5. Exit
Enter your choice: 5
Program Ended
Colab paid products - Cancel contracts here

# %%
entered_persons = set()
rejected_persons = set()

num_persons = 5

print("Event Tracker: Enter 5 persons\n")

for i in range(num_persons):
    name = input(f"Enter name of person {i+1}: ").strip()

    if name in entered_persons:
        print(f"Entry rejected! {name} has already entered.")
        rejected_persons.add(name)
    else:
        print(f"Entry accepted! Welcome {name}.")
        entered_persons.add(name)

print("\n--- Event Entry Summary ---")
print(f"Persons entered successfully ({len(entered_persons)}): {', '.join(entered_persons)}")
print(f"Persons rejected ({len(rejected_persons)}): {', '.join(rejected_persons)}")
print(f"Total persons who entered: {len(entered_persons)}")
print(f"Total persons rejected / duplicate entries: {len(rejected_persons)}")
print(f"Total persons not entered: {num_persons - len(entered_persons)}")

# %%
entered_persons = set()
rejected_persons = set()

n = int(input("Enter the number of persons: "))

for i in range(n):
    name = input("Enter name of person: ")

    if name in entered_persons:
        print(name, "Entry rejected!")
        rejected_persons.add(name)
    else:
        print(name, "Entry accepted!")
        entered_persons.add(name)

print("Event Tracker!")

print("Total entered persons:")
for name in entered_persons:
    print(name)

print("Rejected persons:")
for name in rejected_persons:
    print(name)

# %%
rooms = {
    101: None,
    102: None,
    103: None,
    104: None,
    105: None
}

while True:
    print("\n1. View Rooms")
    print("2. Book Room")
    print("3. Cancel Booking")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        for room, name in rooms.items():
            if name is None:
                print(room, "is available")
            else:
                print(room, "is booked by", name)

    elif choice == 2:
        room = int(input("Enter room number: "))
        if rooms.get(room) is None:
            name = input("Enter your name: ")
            rooms[room] = name
            print("Room booked successfully")
        else:
            print("Room already booked")

    elif choice == 3:
        room = int(input("Enter room number: "))
        if rooms.get(room) is not None:
            rooms[room] = None
            print("Booking cancelled")
        else:
            print("Room is already empty")

    elif choice == 4:
        print("Thank you!")
        break

    else:
        print("Invalid choice")

# %%
students = {}   # student_id : {name, courses}
courses = {}    # course_id : course_name

while True:
    print("\n1. Add Student")
    print("2. Add Course")
    print("3. Enroll Student")
    print("4. Mark Attendance")
    print("5. Assign Grade")
    print("6. Drop Course")
    print("7. Student Report")
    print("8. Course-wise Report")
    print("9. Exit")

    choice = input("Enter your choice: ")



    if choice == '1':
        sid = input("Enter Student ID: ")
        name = input("Enter Student Name: ")
        students[sid] = {"name": name, "courses": {}}
        print("Student added successfully!")


    elif choice == '2':
        cid = input("Enter Course ID: ")
        cname = input("Enter Course Name: ")
        courses[cid] = cname
        print("Course added successfully!")


    elif choice == '3':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in courses:
            students[sid]["courses"][cid] = {"attendance": 0, "grade": None}
            print("Student enrolled successfully!")
        else:
            print("Invalid Student or Course ID")


    elif choice == '4':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in students[sid]["courses"]:
            students[sid]["courses"][cid]["attendance"] += 1
            print("Attendance marked!")
        else:
            print("Enrollment not found")


    elif choice == '5':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")
        grade = input("Enter Grade: ")

        if sid in students and cid in students[sid]["courses"]:
            students[sid]["courses"][cid]["grade"] = grade
            print("Grade assigned successfully!")
        else:
            print("Enrollment not found")


    elif choice == '6':
        sid = input("Enter Student ID: ")
        cid = input("Enter Course ID: ")

        if sid in students and cid in students[sid]["courses"]:
            del students[sid]["courses"][cid]
            print("Course dropped successfully!")
        else:
            print("Enrollment not found")


    elif choice == '7':
        sid = input("Enter Student ID: ")

        if sid in students:
            print("\nStudent Name:", students[sid]["name"])
            for cid, details in students[sid]["courses"].items():
                print("Course:", courses[cid],
                      "| Attendance:", details["attendance"],
                      "| Grade:", details["grade"])
        else:
            print("Student not found")


    elif choice == '8':
        cid = input("Enter Course ID: ")

        if cid in courses:
            print("\nCourse Name:", courses[cid])
            for sid, sdata in students.items():
                if cid in sdata["courses"]:
                    details = sdata["courses"][cid]
                    print("Student:", sdata["name"],
                          "| Attendance:", details["attendance"],
                          "| Grade:", details["grade"])
        else:
            print("Course not found")


    elif choice == '9':
        print("Program terminated.")
        break

    else:
        print("Invalid choice, try again!")
